# %%
import yt

# %%
ds = yt.load("Data_000002")
# Out:
# yt : [WARNING  ] 2020-03-27 22:56:59,340 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2020-03-27 22:56:59,341 Assuming   length unit = 1.000000 cm
# yt : [WARNING  ] 2020-03-27 22:56:59,342 Assuming     time unit = 1.000000 s
# yt : [WARNING  ] 2020-03-27 22:56:59,343 Assuming     mass unit = 1.000000 g
# yt : [WARNING  ] 2020-03-27 22:56:59,344 Assuming magnetic unit = 3.544908 gauss
# yt : [INFO     ] 2020-03-27 22:56:59,358 Parameters: current_time              = 0.001
# yt : [INFO     ] 2020-03-27 22:56:59,358 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2020-03-27 22:56:59,359 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-03-27 22:56:59,360 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2020-03-27 22:56:59,361 Parameters: cosmological_simulation   = 0

# %%
slc = yt.SlicePlot(ds, "z", ["density","pressure","velocity_x","velocity_y"], width=(0.25,"unitary"))
slc.annotate_particles(1.0, stride=100)
# Out:
# /Users/jzuhone/Source/yt/yt/frontends/gamer/data_structures.py:87: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   grid_corner      = self._handle['Tree/Corner'].value[::self.pgroup]
# /Users/jzuhone/Source/yt/yt/frontends/gamer/data_structures.py:121: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   np.sum( self._handle['Tree/NPar'].value.reshape(-1,self.pgroup), axis=1 )[:,None]
# /Users/jzuhone/Source/yt/yt/frontends/gamer/data_structures.py:132: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   son_list = self._handle["Tree/Son"].value
# yt : [INFO     ] 2020-03-27 22:57:00,500 xlim = 0.375000 0.625000
# yt : [INFO     ] 2020-03-27 22:57:00,501 ylim = 0.375000 0.625000
# yt : [INFO     ] 2020-03-27 22:57:00,502 xlim = 0.375000 0.625000
# yt : [INFO     ] 2020-03-27 22:57:00,503 ylim = 0.375000 0.625000
# ...
